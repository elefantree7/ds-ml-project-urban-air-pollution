# %% [markdown]
# # Modeling
# steps:
# - Preprocessing the test set like the train data
# - Scaling the data (test and train)
# - function for model_evaluation
# - function for model building

# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn import preprocessing
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict, cross_validate
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
from sklearn.metrics import fbeta_score, make_scorer, f1_score, accuracy_score

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV

import importlib
import preprocessing_mel
importlib.reload(preprocessing_mel)
from preprocessing_mel import preprocess_minimal

RSEED = 42

# %% [markdown]
# ## Scaling the data

# %% [markdown]
# ## Modeling

# %%
df = pd.read_csv('data/Train.csv')

# %%
X = df.drop(columns=['target', 'target_min', 'target_max', 
                     'target_variance', 'target_count'])
y = df['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RSEED,)
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
# Train: Fit transformers on training data
X_train_proc, y_train_proc = preprocess_minimal(
    df=X_train,
    y=y_train,
    fit_data=X_train  #  Learn from training data
)

# Test: Apply training transformers
X_test_proc, y_test_proc = preprocess_minimal(
    df=X_test,
    y=y_test,
    fit_data=X_train  #  Use training statistics (NO LEAKAGE!)
)

# Drop non-numeric columns
cols_to_drop = ['Date', 'Place_ID', 'Place_ID X Date']
X_train_final = X_train_proc.drop(columns=cols_to_drop, errors='ignore')
X_test_final = X_test_proc.drop(columns=cols_to_drop, errors='ignore')

y_train_final = y_train_proc
y_test_final = y_test_proc

print(f"✅ X_train: {X_train_final.shape}, y_train: {y_train_final.shape}")
print(f"✅ X_test: {X_test_final.shape}, y_test: {y_test_final.shape}")
# Out:
# ✅ X_train: (24445, 74), y_train: (24445,)
# ✅ X_test: (6112, 74), y_test: (6112,)

# %%
X_train_final.isna().sum()
# Out:
# precipitable_water_entire_atmosphere    0
# relative_humidity_2m_above_ground       0
# specific_humidity_2m_above_ground       0
# temperature_2m_above_ground             0
# u_component_of_wind_10m_above_ground    0
#                                        ..
# L3_CH4_aerosol_optical_depth            0
# L3_CH4_sensor_azimuth_angle             0
# L3_CH4_sensor_zenith_angle              0
# L3_CH4_solar_azimuth_angle              0
# L3_CH4_solar_zenith_angle               0
# Length: 74, dtype: int64

# %%
list_of_clf = [LinearRegression(),
               KNeighborsRegressor(),
               RandomForestRegressor(),
               GradientBoostingRegressor()
               ]

tscv = TimeSeriesSplit(n_splits=5)

scorers = {
    'r2': 'r2',
    'rmse': make_scorer(mean_squared_error, greater_is_better=False, squared=False)
}

def model_evaluation(estimator, scoring, X_train_final, y_train_final, cv=tscv):
    return cross_validate(estimator, X_train_final, y_train_final, cv=cv, scoring=scoring, return_train_score=False)

for reg in list_of_clf:
    results = model_evaluation(reg, scorers, X_train_final, y_train_final, cv=5)
    print(reg)
   
    r2_mean, r2_std = results['test_r2'].mean(), results['test_r2'].std()
    rmse_mean, rmse_std = (-results['test_rmse']).mean(), (-results['test_rmse']).std()  # Vorzeichen umdrehen
    print(f'R²   (mean ± std): {r2_mean:.3f} ± {r2_std:.3f}')
    print(f'RMSE (mean ± std): {rmse_mean:.3f} ± {rmse_std:.3f}')
    print('----'*10)
# Out:
# LinearRegression()
# R²   (mean ± std): 0.374 ± 0.018
# RMSE (mean ± std): 37.052 ± 0.830
# ----------------------------------------
# KNeighborsRegressor()
# R²   (mean ± std): 0.415 ± 0.025
# RMSE (mean ± std): 35.810 ± 0.923
# ----------------------------------------
# RandomForestRegressor()
# R²   (mean ± std): 0.581 ± 0.027
# RMSE (mean ± std): 30.298 ± 1.251
# ----------------------------------------
# GradientBoostingRegressor()
# R²   (mean ± std): 0.489 ± 0.024
# RMSE (mean ± std): 33.468 ± 1.157
# ----------------------------------------

# %% [markdown]
# ## Hyperparameter Tuning
#
# - LinearRegression - GradientDescent
# - KNN - GridSearchCV?
# - Decision Tree - GridSearchCV?

# %% [markdown]
# ## KNNReg parametertuning

# %%
KNeighborsRegressor().get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
# Defining parameter grid (as dictionary)
param_grid = {"n_neighbors" : [3,5,10], #this actually defines the model you use
              "weights" : ["uniform", "distance"],
              "p" : [1, 2],
              "algorithm": ["ball_tree"],
              "leaf_size": [30],
              "weights": ["uniform", "distance"],
             }

# Instantiate gridsearch and define the metric to optimize 
gs = GridSearchCV(KNeighborsRegressor(), param_grid, scoring='neg_root_mean_squared_error',
                  cv=5, verbose=2, n_jobs=-1)

# Fit gridsearch object to data.. also lets see how long it takes

gs.fit(X_train_final, y_train_final)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=uniform; total time=  13.6s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=uniform; total time=  14.2s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=distance; total time=  14.7s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=uniform; total time=  18.7s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=uniform; total time=  18.8s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=distance; total time=  18.9s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=uniform; total time=  19.1s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=distance; total time=  19.2s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=distance; total time=  14.0s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=1, weights=distance; total time=  13.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=uniform; total time=  15.2s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=uniform; total time=  20.8s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=uniform; total time=  20.7s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=uniform; total time=  20.9s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=distance; total time=  20.6s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=uniform; total time=  20.9s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=distance; total time=  14.3s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=distance; total time=  14.9s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=distance; total time=  14.6s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=  13.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=  13.8s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=  17.7s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=  17.8s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=  13.3s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=  18.5s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=uniform; total time=  18.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, p=2, weights=distance; total time=  20.7s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=  14.1s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=  14.0s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=  15.6s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=1, weights=distance; total time=  20.3s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=  21.9s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=  22.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=  22.6s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=uniform; total time=  22.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=  15.0s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=  15.1s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=  15.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=  14.0s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=  20.8s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=  18.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=  14.1s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=  18.6s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, p=2, weights=distance; total time=  21.2s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=uniform; total time=  18.8s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=  13.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=  14.0s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=  13.8s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=  15.4s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=  19.6s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=1, weights=distance; total time=  20.1s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=  20.9s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=  22.3s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=  22.1s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=uniform; total time=  14.7s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=  14.3s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=  12.0s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=  12.5s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=  13.5s
# [CV] END algorithm=ball_tree, leaf_size=30, n_neighbors=10, p=2, weights=distance; total time=  11.0s
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'algorithm': ['ball_tree'], 'leaf_size': [30],
#                          'n_neighbors': [3, 5, 10], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
# Best score
print('Best score:', -round(gs.best_score_, 3))

# Best parameters
print('Best parameters:', gs.best_params_)
# Out:
# Best score: 34.804
# Best parameters: {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}

# %%
# Assigning the fitted KNNClassifier model with best parameter combination to a new variable knn_best
knn_best_gs = gs.best_estimator_

# Making predictions on the train set
y_pred_knn = knn_best_gs.predict(X_test_final)

print("R2 on train:", round(r2_score(y_test_final, y_pred_knn),3))
# Out:
# R2 on train: 0.465

# %%
def print_pretty_summary(name, y_actual, y_pred):
    print(name)
    print('=======================')
    
    r2 = r2_score(y_actual, y_pred)
    rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
    
    print(f"R²:   {r2:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print()

# %%
print_pretty_summary("KNNreg",y_test, y_pred_knn)
# Out:
# KNNreg
# =======================
# R²:   0.465
# RMSE: 34.308

# %% [markdown]
# ## RandomForestReg parametertuning

# %%
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# --- CV und Scorer definieren ---
tscv = TimeSeriesSplit(n_splits=5)
rmse_scorer = make_scorer(mean_squared_error, greater_is_better=False, squared=False)

# --- Modell ---
rf = RandomForestRegressor(random_state=42, n_jobs=-1)

# --- Parameter-Raum ---
param_dist = {
    "n_estimators": [200, 400],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2],
    "max_features": ["sqrt"],
    "bootstrap": [True],
}

# --- Randomized Search ---
rand_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=30,                  # Anzahl zufälliger Kombinationen
    scoring=rmse_scorer,
    cv=tscv,
    n_jobs=-1,
    random_state=42,
    verbose=2,
    refit=True
)

rand_search.fit(X_train_final, y_train_final)

# --- Ergebnisse ---
print("\nBeste Parameterkombination:")
print(rand_search.best_params_)
print("Bester RMSE (CV):", -rand_search.best_score_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /Users/melaniesass/neueFische/ds-ml-project-urban-air-pollution/.venv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 24 is smaller than n_iter=30. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  10.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  15.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  21.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  23.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   9.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   9.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  34.2s
# /Users/melaniesass/neueFische/ds-ml-project-urban-air-pollution/.venv/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  19.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  45.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  27.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  27.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  59.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  21.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  40.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  17.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  27.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  56.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  32.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  18.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   7.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  28.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  44.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  30.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  15.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  58.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  44.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  23.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   7.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  28.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  57.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  16.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  13.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   6.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  36.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  19.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   7.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  18.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  27.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  14.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  20.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  33.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   9.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  12.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  25.1s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  17.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  14.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  36.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  23.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  10.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  18.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  33.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  26.3s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  39.6s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  24.1s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  32.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.8s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  34.1s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  19.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  19.1s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  42.3s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  25.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   8.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  30.3s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  56.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  18.3s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  39.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  19.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  28.9s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   9.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  54.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  17.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  41.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  46.8s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  22.2s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  27.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  28.7s
#
# Beste Parameterkombination:
# {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': True}
# Bester RMSE (CV): 32.43310152614999

# %%
print("Best RMSE (CV):", -round(rand_search.best_score_, 3))
print("Best Parameters:", rand_search.best_params_)
# Out:
# Best RMSE (CV): 32.433
# Best Parameters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': True}

# %%
# Assigning the fitted random forest classifier model with best parameter combination to a new variable rf_best_gs
rf_best_rs = rand_search.best_estimator_

# Making predictions on the train set
y_pred_rf = rf_best_rs.predict(X_test_final)

print("R2 on train:", round(r2_score(y_test_final, y_pred_rf),3))
# Out:
# R2 on train: 0.565

# %%
print_pretty_summary("Random Forest",y_test_final, y_pred_rf)
# Out:
# Random Forest
# =======================
# R²:   0.565
# RMSE: 30.951

# %%
from sklearn.inspection import permutation_importance

# --- Permutation importance ---
r = permutation_importance(
    rf_best_rs, 
    X_test_final, 
    y_test_final,
    n_repeats=10, 
    random_state=42, 
    n_jobs=-1
)

perm_imp = pd.DataFrame({
    "feature": X_test_final.columns,
    "importance": r.importances_mean
}).sort_values("importance", ascending=False)

print("\nPermutation Feature Importance:")
print(perm_imp.head(20))
# Out:
# /Users/melaniesass/neueFische/ds-ml-project-urban-air-pollution/.venv/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Permutation Feature Importance:
#                                               feature  importance
# 53                          L3_AER_AI_sensor_altitude    0.100691
# 25                     L3_CO_CO_column_number_density    0.083534
# 7              L3_NO2_NO2_slant_column_number_density    0.055655
# 39    L3_HCHO_tropospheric_HCHO_column_number_density    0.043649
# 3                         temperature_2m_above_ground    0.038016
# 4                u_component_of_wind_10m_above_ground    0.036533
# 6                    L3_NO2_NO2_column_number_density    0.034143
# 10                             L3_NO2_sensor_altitude    0.030400
# 5                v_component_of_wind_10m_above_ground    0.024370
# 28                              L3_CO_sensor_altitude    0.022221
# 40  L3_HCHO_tropospheric_HCHO_column_number_densit...    0.021572
# 33           L3_HCHO_HCHO_slant_column_number_density    0.019035
# 2                   specific_humidity_2m_above_ground    0.018504
# 17      L3_NO2_tropospheric_NO2_column_number_density    0.016398
# 16                         L3_NO2_tropopause_pressure    0.011958
# 57                       L3_AER_AI_solar_zenith_angle    0.009796
# 44                       L3_CLOUD_cloud_optical_depth    0.009685
# 18                     L3_O3_O3_column_number_density    0.009484
# 19                     L3_O3_O3_effective_temperature    0.009419
# 56                      L3_AER_AI_solar_azimuth_angle    0.009051

# %%
import matplotlib.pyplot as plt

# Take top 15 most important features
top_n = 15
top_imp = perm_imp.head(top_n).sort_values("importance")

plt.figure(figsize=(10, 6))
plt.barh(top_imp["feature"], top_imp["importance"])
plt.xlabel("Permutation Importance (Decrease in Model Score)")
plt.ylabel("Feature")
plt.title("Top Feature Drivers of PM2.5 Predictions")
plt.tight_layout()
plt.show()
